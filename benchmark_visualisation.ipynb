# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import *
from NN_alg import *

# %%
small_set_20 = pd.read_csv('data/cities_20.csv')
medium_set_50 = pd.read_csv('data/cities_50.csv')
large_set_100 = pd.read_csv('data/cities_100.csv')

# %%
dist_df_20 = pd.read_csv('data/dist_df_20.csv').values
dist_df_50 = pd.read_csv('data/dist_df_50.csv').values
dist_df_100 = pd.read_csv('data/dist_df_100.csv').values

# %%
tour_20 = nearest_neighbor(dist_df_20)
tour_50 = nearest_neighbor(dist_df_50)
tour_100 = nearest_neighbor(dist_df_100)

plot_tsp_route(small_set_20, tour_20, dist_df_20, "Nearest Neighbor dla 20 miast")
plot_tsp_route(medium_set_50, tour_50, dist_df_50, "Nearest Neighbor dla 50 miast")
plot_tsp_route(large_set_100, tour_100, dist_df_100, "Nearest Neighbor dla 100 miast")
